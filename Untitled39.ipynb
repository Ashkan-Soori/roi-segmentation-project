# %%
def test_fill_holes_actually_fills_internal_gaps():
    """
    This test creates a fully enclosed hole.

    The algorithm should detect and fill it.
    """

    mask = np.array([
        [255,255,255,255,255],
        [255,0,0,0,255],
        [255,0,255,0,255],  # hole in center
        [255,0,0,0,255],
        [255,255,255,255,255]
    ], dtype=np.uint8)

    result = fill_holes(mask)

    assert result[2,2] == 0
